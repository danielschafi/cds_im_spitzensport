# %%
import pandas as pd
import matplotlib.pyplot as plt

from physics_computer.ski_alpine import SkiAlpine
# Out:
#   Cell In[1], line 5
#     from physics_computer.base import
#                                       ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv("/home/schafhdaniel@edu.local/cds_im_spitzensport/data_gps/DH_W_1.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("/home/schafhdaniel@edu.local/cds_im_spitzensport/data_gps/DH_W_1.csv")
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#      Unnamed: 0  elevation   latitude   longitude  speedD  speedE  speedN  \
# 0             0   3220.121  39.574064 -106.513726   8.073 -16.281   4.245
# 1             1   3219.201  39.574069 -106.513746   8.199 -16.741   4.626
# 2             2   3218.249  39.574073 -106.513765   8.348 -16.687   5.202
# 3             3   3217.287  39.574079 -106.513785   8.484 -17.005   5.610
# 4             4   3216.287  39.574084 -106.513805   8.665 -17.271   5.921
# ..          ...        ...        ...         ...     ...     ...     ...
# 565         565   2738.002  39.583392 -106.523442  12.438 -22.162  26.777
# 566         566   2736.782  39.583416 -106.523467  12.401 -22.149  26.933
# 567         567   2735.656  39.583441 -106.523494  12.270 -22.169  27.241
# 568         568   2734.606  39.583465 -106.523520  12.060 -22.357  27.318
# 569         569   2733.558  39.583490 -106.523547  11.870 -22.494  27.470
#
#      run   tf_id discipline_from_name              timestamp
# 0      1  109576                   DH  20241213T182624000000
# 1      1  109576                   DH  20241213T182624100000
# 2      1  109576                   DH  20241213T182624200000
# 3      1  109576                   DH  20241213T182624300000
# 4      1  109576                   DH  20241213T182624400000
# ..   ...     ...                  ...                    ...
# 565    1  109576                   DH  20241213T182720500000
# 566    1  109576                   DH  20241213T182720600000
# 567    1  109576                   DH  20241213T182720700000
# 568    1  109576                   DH  20241213T182720800000
# 569    1  109576                   DH  20241213T182720900000
#
# [570 rows x 11 columns]

# %%
alpine = SkiAlpine(df)
df_modified = alpine.compute()
# Out:
# 2025-09-25 12:16:56.640 | INFO     | physics_computer.base:_modify_config:57 - running _modify_config ...
# 2025-09-25 12:16:56.642 | INFO     | physics_computer.base:_convert_timestamp:148 - running _convert_timestamp ...
# 2025-09-25 12:16:56.664 | INFO     | physics_computer.base:_convert_coordinates:100 - running _convert_coordinates ...
# 2025-09-25 12:16:56.734 | INFO     | physics_computer.base:_compute_absolute_value:210 - running _compute_absolute_value ...
# 2025-09-25 12:16:56.801 | INFO     | physics_computer.base:_compute_tangential_vector:235 - running _compute_tangential_vector ...
# 2025-09-25 12:16:56.866 | INFO     | physics_computer.base:_compute_k:253 - running _compute_k ...
# 2025-09-25 12:16:57.011 | INFO     | physics_computer.base:_compute_k_xy:274 - running _compute_k_xy ...
# 2025-09-25 12:16:57.050 | INFO     | physics_computer.base:_compute_slope:293 - running _compute_slope ...
# 2025-09-25 12:16:57.087 | INFO     | physics_computer.base:_compute_accelerations:336 - running _compute_accelerations ...
# 2025-09-25 12:16:57.476 | INFO     | physics_computer.base:_compute_ifly:400 - running _compute_ifly ...

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Scatter3d(
    x=df['longitude'],
    y=df['latitude'],
    z=df['elevation'],
    mode='lines',
    name='Ski Track',
    line=dict(color='blue', width=4)
)])

fig.update_layout(
    scene=dict(
        xaxis_title='Longitude',
        yaxis_title='Latitude',
        zaxis_title='Elevation (m)'
    ),
    title='3D Ski Track',
    legend=dict(x=0, y=1)
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/spitzensport/lib/python3.12/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/miniconda3/envs/spitzensport/lib/python3.12/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/miniconda3/envs/spitzensport/lib/python3.12/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'line': {'color': 'blue', 'width': 4},
#               'mode': 'lines',
#               'name': 'Ski Track',
#               'type': 'scatter3d',
#               'x': {'bdata': ('4MWx5OCgWsDaHOc24aBawOCUA4fhoF' ... 'rh6oChWsBTswdagaFawKY7mcmBoVrA'),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('jCZh8HrJQ0CLVHMUe8lDQHRAtzx7yU' ... 'SlLa7KQ0C+bQH8rspDQFlGNMuvykNA'),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('okW28z0oqUD+1HjpZiapQGiR7Xx/JK' ... 'Q7309fpUDByqFFNl2lQFYOLbIdW6VA'),
#                     'dtype': 'f8'}}],
#     'layout': {'legend': {'x': 0, 'y': 1},
#                'scene': {'xaxis': {'title': {'text': 'Longitude'}},
#                          'yaxis': {'title': {'text': 'Latitude'}},
#                          'zaxis': {'title': {'text': 'Elevation (m)'}}},
#                'template': '...',
#                'title': {'text': '3D Ski Track'}}
# })
